# %%
list1 = [1,2,3]
list2 = [4,5,6]

list1.append(list2)
list1
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
list1.extend(list2)
list1
# Out:
# [1, 2, 3, [4, 5, 6], 4, 5, 6]

# %%
list1.insert(3,9)
list1
# Out:
# [1, 2, 3, 9, [4, 5, 6], 4, 5, 6]

# %%
list1[4] = 10
list1
# Out:
# [1, 2, 3, 9, 10, 4, 5, 6]

# %%
na = "My Name Is. Rush"

print(na.lower())
print(na.upper())
print(na.capitalize())
# Out:
# my name is. rush
# MY NAME IS. RUSH
# My name is. rush

# %%
ll= [9]*3
ll
# Out:
# [9, 9, 9]
