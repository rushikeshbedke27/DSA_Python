# %% [markdown]
# # ------ Basic DSA Questions ------

# %% [markdown]
# ## 1. FizzBuzz

# %% [raw]
# i. ans[i] == "FizzBuzz" if i is divisible by 3 and 5
# ii. ans[i] == "Fizz" if i is divisible by 3
# iii. ans[i] == "Buzz" if i is divisible by 5
# iv. ans[i] == i (as a String) if none of above conditions are true.

# %%
from typing import List

class FizzBuzz:
    def fizzBuzz(self, n: int) -> List[str]:
        ans = []
        for i in range(1, n+1):
            if i%3==0 and i%5==0:
                ans.append("FizzBuzz")
            elif i%3==0:
                ans.append("Fizz")
            elif i%5==0:
                ans.append("Buzz")
            else:
                ans.append(str(i))
        return ans

fz = FizzBuzz()
print(fz.fizzBuzz(15))
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %% [raw]
# n: int -        In the above code (self, n: int) here int defines the datatype of n. If we pass any string it will show error.
# -> List[str] -  It shows the return type of the function is List of string. It is use to only purpose for understandig, it is not                          mandatory, Becz we are also returning the list ans thats why.

# %% [markdown]
# ## 2. find Odd nums betn specific range

# %% [raw]
# Give two non -ve integer low and high. Return the count of odd nums betn low and high (inclusive)
# ex1: inp: low=3, high=7
#     out: 3
#     exp: 3,5,7 - these are the only odd numd betn 3-
# ex2: inp: low=8, high=10
#     out: 1
#     exp: 9 is the only odd num

# %%
class CountOdds:
    def countOdds(self, low: int, high: int) -> int:
        return (high+1)//2 - (low//2)

odd = CountOdds()
odd.countOdds(3,13)
# Out:
# 6

# %% [raw]
# Logic:
# i. Here we are counting odd nums from 1 to high+1 and then minus(-) the odd nums from 1 to low. So we get odd nums from low to high.
# ii. And we use floor division // to get exact num, if not use floor then we get ans in the float format, and not get exact integer count.
# iii. -> int is used to understand the our return typr is int. Same for the int whis is near to the paramter inside the round bracket.

# %% [markdown]
# ## 3. How many numbers are the smaller than the current num.

# %% [raw]
# Given the array nums, for each nums[i] find out how many numbers in the array are smaller than it. That is, for each nuns [i] you have to count nuns the number of valid j's such that j != 1 and nums[j] <nums[i]
# Return the answer in an array.
# Example 1:
# Input: nums [8,1,2,2,3]
# Output: 14,0,1,1,3)
# Explanation:
# For nums[0]=8 there exist four smaller numbers than it (1, 2, 2 and 3).
# For nums[1]=1 does not exist any smaller number than it.
# For nums [2]=2 there exist one smaller number than it (1).
# For nums [3]=2 there exist ane smaller number than it (1).
# 30 For nums [4]=3 there exist three smaller numbers than it (1, 2 and 2).

# %%
from typing import List
class SmallerNumThanCurrent:
    def smallerNumThanCurrent(self, nums: List[int]) -> List[int]:
        ans = []
        for i in nums:
            c = 0
            for j in nums:
                if j < i:
                    c+=1
            ans.append(c)
        return ans

l1 = [8,1,2,2,3]
sntc = SmallerNumThanCurrent()
sntc.smallerNumThanCurrent(l1)
# Out:
# [4, 0, 1, 1, 3]

# %% [markdown]
# ## 4 Count the digits that divide a num

# %% [raw]
# Given an integer num, return the number of digits in num that divide num.
# An integer val divides nums if nums % val == 0
# Example 1:
# Input: num = 7
# Output: 1
# Explanation: 7 divides itself, hence the answer is 1.
#
# Example 2:
# Input: num = 121
# Output: 2
# Explanation: 121 is divisible by 1, but not 2. Since 1 occurs twice as a digit, we return 2.
#
# Example 3:
# Input: num = 1248
# Output: 4
# Explanation: 1248 is divisible by all of its digits, hence the answer is 4.

# %%
class CountDigits:
    def countDigits(self, num: int) -> int:
        temp = num
        c = 0
        while temp > 0:
            rem = temp % 10
            if num % rem == 0:
                c += 1
            temp //= 10
        return c

num1 = 121
num2 = 1248

cd = CountDigits()
cd.countDigits(num2)
# Out:
# 4

# %% [raw]
# i. rem = temp % 10 -  We are accessing last digit
# ii. temp //= 10 - Here we are removing last digit and remains num in it like this (temp = temp//10)

# %% [markdown]
# ## 5. Checking number is palindrom or not

# %% [raw]
# Example 1:
# Input: x = 121
# Output: true
# Explanation: 121 reads as 121 from left to right and from right to left.
#
# Example 2:
# Input: x = -121
# Output: false
# Explanation: From left to right, it reads -121. From right to left, it becomes 121-. Therefore it is not a palindrome.
#
# Example 3:
# Input: x = 10
# Output: false
# Explanation: Reads 01 from right to left. Therefore it is not a palindrome.

# %%
class IsPalindrome:
    def isPalindrome(self, num: int) -> bool:
        temp = num
        x = 0
        while temp > 0:
            rem = temp % 10
            x = (x * 10) + rem
            temp //= 10
        return num == x

pal = IsPalindrome()
pal.isPalindrome(12221)
# Out:
# True

# %% [markdown]
# ## 6. Subtract the product and sum of digits of it's digit.

# %% [raw]
# Given an integer number n, return the difference between the product of its digits and the sum of its digits.
# Example 1:
#     Input: n = 234
#     Output: 15
#     Explanation: Product of digits 2* 3 * 4 = 24. Sum of digits = 2 + 3 + 4 = 9 Result = 15
# Example 2:
#     Input: n = 4421
#     Output: 21
#     Explanation: Product of digits 4 * 4 * 2 * 1 = 32. Sum of digits = 4 + 4 + 2 + 1 = 11 Result = 21

# %%
class SubtractProductAndSum:
    def subtractProductAndSum(self, n: int) -> int:
        temp = n
        pro = 1
        add = 0
        while temp > 0:
            rem = temp % 10
            pro *= rem
            add += rem
            temp //= 10
        
        return pro - add

spas = SubtractProductAndSum()
spas.subtractProductAndSum(4421)
# Out:
# 21

# %% [markdown]
# ## 7. Kids with the greatest num of candies

# %% [raw]
# There are n kids with candies. You are given an integer array candies. where each candies[i] represents the number of candies the i'th kid has, and an integer extraCandies, denoting the number of extra candies that you have
# Return a boolean array result of length n, where result[i] is true if, after giving the i'th kid all the extraCandies, they will have the greatest number of candies among all the kids, or false otherwise.
#
# Note that multiple kids can have the greatest number of candies.
#
# Example 1:
# Input: candies [2,3,5,1,3), extraCandies = 3
# Output: [true, true, true, false, true)
# Explanation: If you give all extraCandies to:
# Kid 1, they will have 2+3=5 candies, which is the greatest among the kids.
# Kid 2, they will have 3+3=6 candies, which is the greatest among the kids.
# Kid 3, they will have 5+3=8 candies, which is the greatest among the kids.
# Kid 4, they will have 1+3=4 candies, which is not the greatest among the kids.
# Kid 5, they will have 3+3=6 candies, which is the greatest among the kids.

# %%
# Method 1
# class KidsWithCandies:
#     def kidsWithCandies(self, candies: List[int], extraCandies: int) -> List[bool]:
#         out = []
#         for i in candies:
#             if (i+extraCandies) >= max(candies):
#                 out.append(True)
#             else:
#                 out.append(False)
#         return out

# Method 2:
class KidsWithCandies:
    def kidsWithCandies(self, candies: List[int], extraCandies: int) -> List[bool]:
      return [(i+extraCandies)>= max(candies)  for i in candies]

# =================================================================================================
candies = [2,3,5,1,3]
kwc = KidsWithCandies()
kwc.kidsWithCandies(candies, 3)
# Out:
# [True, True, True, False, True]
